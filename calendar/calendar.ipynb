# %%
import polars as pl
from great_tables import GT, md, html

(
 GT(pl.read_excel('Calendar.xlsx')).tab_header(title="Course Calendar").tab_stubhead(label=md("*Date*"))
    .tab_stub(rowname_col="Date", groupname_col="Week")
    .cols_hide(['Type']).fmt_markdown('Readings').sub_missing(
        columns=["Topics", "Readings", "Materials"],
        missing_text=""
    )
)
# Out:
# GT(_tbl_data=shape: (14, 7)
# ┌────────┬────────────┬──────────┬────────────────────┬───────────────────┬───────────┬────────────┐
# │ Week   ┆ Date       ┆ Type     ┆ Topics             ┆ Readings          ┆ Materials ┆ Name       │
# │ ---    ┆ ---        ┆ ---      ┆ ---                ┆ ---               ┆ ---       ┆ ---        │
# │ str    ┆ date       ┆ str      ┆ str                ┆ str               ┆ null      ┆ str        │
# ╞════════╪════════════╪══════════╪════════════════════╪═══════════════════╪═══════════╪════════════╡
# │ Week 1 ┆ 2024-08-26 ┆ lecture  ┆ Course             ┆ [538](https://pro ┆ null      ┆ Lecture 0  │
# │        ┆            ┆          ┆ introduction       ┆ jects.fivethi…    ┆           ┆            │
# │ Week 1 ┆ 2024-08-28 ┆ lecture  ┆ Tidy data, data    ┆ null              ┆ null      ┆ Lecture 1  │
# │        ┆            ┆          ┆ types              ┆                   ┆           ┆            │
# ...
